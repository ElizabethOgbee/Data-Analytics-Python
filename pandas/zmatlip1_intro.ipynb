# %% [markdown]
# WHAT IS MATPLOTLIB:
#
# matplotlib is a plotting library that let's you turn data into visual insights using charts, graphs and plots
#
# It's great for:
# - Time series analysis(line plots)
# - Comparing groups(bar plots)
# - Showing distribution(histogram)
# - Data relationships(scatter plots)
#
# WE WILL MAINLY USE IT WITH PANDAS
#
# install but: import matplotlib.pyplot as plt

# %%
#import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# create my first plot
# 
# sample data#

year = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
population = [162, 166, 170, 174, 178, 182, 186, 190, 195, 200]

#plotting
plt.figure(figsize=(10, 5))
plt.plot(year, population, marker='*')
plt.title('Nigeria Population Growth')
plt.xlabel('Year')
plt.ylabel('Population (millions)')
plt.grid(True)
plt.tight_layout()
plt.show()

# plt.plot() draws the line
# plt.title() adds a title
# plt.xlabel() and plt.ylabel() label the axes
# plt.show() renders the plot

# %% [markdown]
# BAR AND PIE CHART
#
# Got it — so instead of just having years on the x-axis, you want categories as well, right?
#
# For example:
#
# If we stick to the Nigerian population dataset, we could split each year into Male and Female populations, USING THE PREVIOUS DATA SET
#
# This will let us create grouped bar charts (multiple bars per year).
#
# | Year | Male | Female |
# | ---- | ---- | ------ |
# | 2011 | 80   | 82     |
# | 2012 | 82   | 84     |
# | 2013 | 85   | 85     |
# | 2014 | 86   | 88     |
# | 2015 | 88   | 90     |
# | 2016 | 91   | 91     |
# | 2017 | 93   | 93     |
# | 2018 | 95   | 95     |
# | 2019 | 97   | 98     |
# | 2020 | 99   | 101    |

# %%
# Data
years = [2010, 2012, 2014, 2016, 2018, 2020]
population = [158, 170, 182, 193, 206, 214]  # millions

# BAR CHART
plt.figure(figsize=(8, 5))
plt.bar(years, population, color='skyblue', edgecolor='black')
plt.title('Nigerian Population over the years', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Population')
plt.tight_layout()
plt.show()

# %% [markdown]
# HORIZONTAL BAR CHART

# %%
plt.barh(years, population, color='skyblue', edgecolor='black')  # horizontal bars
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population in Nigeria')
plt.show()

# %% [markdown]
# PIE CHART

# %%
plt.figure(figsize=(6, 6))
plt.pie(population, labels=years, autopct='%1.1f%%', startangle=140)
plt.title('Nigeria Population Distribution')
plt.show()

# %%
# Explode: only the first slice pops out (0.1 inch away), others stay at 0
explode = (0.1, 0, 0, 0, 0, 0.1)

plt.figure(figsize=(6, 6))
plt.pie(
    population,
    labels=years,
    autopct='%1.1f%%',
    startangle=140,
    explode=explode,
    shadow=True  # optional, adds shadow for effect
)
plt.title('Nigeria Population Distribution')
plt.show()

# %% [markdown]
# GROUP BAR CHART
#
# A group bar chart allows us to compare male and female population for each year

# %%
import numpy as np

years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
male = [80, 82, 85, 86, 88, 91, 93, 95, 97, 99]
female = [82, 84, 85, 88, 90, 91, 93, 95, 98, 101]

# %%
# set bar width
bar_width = 0.4
x = np.arange(len(years))

# create grouped bars
plt.figure(figsize=(10, 6))
plt.bar(x - bar_width/2, male, width=bar_width, label='Male', color='blue')
plt.bar(x + bar_width/2, female, width=bar_width, label='Female', color='pink')

# Labels & Title
plt.xlabel('Year')
plt.ylabel('Population (millions)')
plt.title('Nigerian Population by Gender (2011-2020)')
plt.xticks(x, years)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
#PIE CHART

# %%
#TOTAL POPULATION FOR EACH GENDER(SUM OVER THE YEARS)
total_male = sum(male)
total_female = sum(female)

#labels and sizes
labels= ['Male', 'Female']
sizes= [total_male, total_female]
colors= ['blue', 'pink']

#create the pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Nigerian Population by Gender (2022-2020)')
plt.axis('equal') #equalaspect ratio ensures the pie is a circle

plt.show()
