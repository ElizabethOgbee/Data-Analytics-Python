# %%
import pandas as pd

print("pandas version", pd.__version__)

#   READING A CSV FILE IN PANDAS
# - WE FIRST LOAD OUR SUPMKT.CSV FILE
# - IF IT'S IN THE SAME FOLDER AS PANDAS WE SIMPLY SAY
# -THEN RUN USING DF.HEAD()#

df = pd.read_csv('supmkt.csv')
df.head()

# - IF IT'S ANOTHER FOLDER, I WILL USE
# SOMETHING LIKE DATA/#
# Out:
# pandas version 2.3.1
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
# ...

# %%
df.tail()
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 4985              NCZ54            CHUKWUDI019              NCZ54_CHUKWUDI019
# 4986              NCZ54            CHUKWUDI027              NCZ54_CHUKWUDI027
# 4987              NCZ54            CHUKWUDI045              NCZ54_CHUKWUDI045
# 4988              NCZ54            CHUKWUDI046              NCZ54_CHUKWUDI046
# 4989              NCZ54            CHUKWUDI049              NCZ54_CHUKWUDI049
#
#       Product_Weight Product_Fat_Content  Product_Shelf_Visibility  \
# 4985             NaN             Low Fat                  0.145952
# 4986             NaN             Low Fat                  0.082956
# 4987           14.65             Low Fat                  0.083528
# 4988           14.65             Low Fat                  0.083359
# 4989           14.65             Low Fat                  0.083489
#
#      Product_Type  Product_Price  Supermarket_Opening_Year Supermarket_Size  \
# ...

# %%
df.shape
# Out:
# (4990, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Product_Identifier              4990 non-null   object
#  1   Supermarket_Identifier          4990 non-null   object
#  2   Product_Supermarket_Identifier  4990 non-null   object
#  3   Product_Weight                  4188 non-null   float64
#  4   Product_Fat_Content             4990 non-null   object
#  5   Product_Shelf_Visibility        4990 non-null   float64
#  6   Product_Type                    4990 non-null   object
#  7   Product_Price                   4990 non-null   float64
#  8   Supermarket_Opening_Year        4990 non-null   int64
#  9   Supermarket_Size                3540 non-null   object
#  10  Supermarket_Location_Type       4990 non-null   object
#  11  Supermarket_Type                4990 non-null   object
# ...

# %%
#- NOW, WE ARE GOING TO FIND WHICH ROWS HAVE MISSING DATA
# -1 CHECK IF ANY VALUE IS MISSING#
df.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                     802
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket_Size                  1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
# TO SHOW ONLY ROWS WITH MISSING VALUES#
df[df.isnull().any(axis=1)]
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 2                 DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 5                 DRA12            CHUKWUDI045              DRA12_CHUKWUDI045
# 6                 DRA24            CHUKWUDI010              DRA24_CHUKWUDI010
# 8                 DRA24            CHUKWUDI017              DRA24_CHUKWUDI017
# ...                 ...                    ...                            ...
# 4981              NCZ53            CHUKWUDI027              NCZ53_CHUKWUDI027
# 4983              NCZ54            CHUKWUDI010              NCZ54_CHUKWUDI010
# 4985              NCZ54            CHUKWUDI019              NCZ54_CHUKWUDI019
# 4986              NCZ54            CHUKWUDI027              NCZ54_CHUKWUDI027
# 4987              NCZ54            CHUKWUDI045              NCZ54_CHUKWUDI045
#
# ...

# %%
# TO SHOW MISSING ROWS IN ONE SPECIFIC COLUMN
# HELPS ME TO FOCUS ON ONE SPECIFIC COLUM#
df[df['Supermarket_Size'].isnull()]
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 2                 DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 5                 DRA12            CHUKWUDI045              DRA12_CHUKWUDI045
# 6                 DRA24            CHUKWUDI010              DRA24_CHUKWUDI010
# 8                 DRA24            CHUKWUDI017              DRA24_CHUKWUDI017
# ...                 ...                    ...                            ...
# 4972              NCZ30            CHUKWUDI017              NCZ30_CHUKWUDI017
# 4975              NCZ41            CHUKWUDI017              NCZ41_CHUKWUDI017
# 4978              NCZ42            CHUKWUDI017              NCZ42_CHUKWUDI017
# 4983              NCZ54            CHUKWUDI010              NCZ54_CHUKWUDI010
# 4987              NCZ54            CHUKWUDI045              NCZ54_CHUKWUDI045
#
# ...

# %% [markdown]
#  PART 2: Accessing Columns and Summarizing Data
# Now that you're exploring your data, here’s how to access and describe it:

# %%
#1. GET ONE COLUMN#
df['Product_Fat_Content']
# Out:
# 0             Low Fat
# 1             Low Fat
# 2             Low Fat
# 3             Low Fat
# 4       Ultra Low fat
#             ...
# 4985          Low Fat
# 4986          Low Fat
# 4987          Low Fat
# 4988          Low Fat
# 4989          Low Fat
# Name: Product_Fat_Content, Length: 4990, dtype: object

# %%
# 2. GET MULTIPLES COLUMN#
df[['Product_Supermarket_Identifier', 'Product_Supermarket_Sales']]
# Out:
#      Product_Supermarket_Identifier  Product_Supermarket_Sales
# 0                 DRA12_CHUKWUDI010                     709.08
# 1                 DRA12_CHUKWUDI013                    6381.69
# 2                 DRA12_CHUKWUDI017                    6381.69
# 3                 DRA12_CHUKWUDI018                    2127.23
# 4                 DRA12_CHUKWUDI035                    2481.77
# ...                             ...                        ...
# 4985              NCZ54_CHUKWUDI019                     406.14
# 4986              NCZ54_CHUKWUDI027                   13808.69
# 4987              NCZ54_CHUKWUDI045                    5685.93
# 4988              NCZ54_CHUKWUDI046                   11778.00
# 4989              NCZ54_CHUKWUDI049                   17870.07
#
# [4990 rows x 2 columns]

# %%
#3. GET BASIC STATS FOR ALL NUMERIC COLUMNS#
df.describe()
# Out:
#        Product_Weight  Product_Shelf_Visibility  Product_Price  \
# count     4188.000000               4990.000000    4990.000000
# mean        12.908838                  0.066916     391.803796
# std          4.703256                  0.053058     119.378259
# min          4.555000                  0.000000      78.730000
# 25%          8.767500                  0.027273     307.890000
# 50%         12.600000                  0.053564     393.860000
# 75%         17.100000                  0.095358     465.067500
# max         21.350000                  0.328391     667.220000
#
#        Supermarket_Opening_Year  Product_Supermarket_Sales
# count               4990.000000                4990.000000
# mean                2004.783567                6103.520164
# std                    8.283151                4447.333835
# min                 1992.000000                  83.230000
# 25%                 1994.000000                2757.660000
# ...

# %%
#4. SEE HOW MANY TIMES EACH VALUE APPEARS FOR (LIKE FOR CATEGORIES)#
df['Supermarket_Opening_Year'].value_counts()
# Out:
# Supermarket_Opening_Year
# 1992    802
# 2006    620
# 1994    594
# 2014    583
# 2011    515
# 2004    509
# 2016    500
# 2009    483
# 2005    384
# Name: count, dtype: int64
